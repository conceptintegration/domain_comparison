# %% [markdown]
# # SAT Installer
#
# Install the the following resources:
#
# - Universal Sentence Encoder (version 4).
# - Pre-compiled model files.
# - Constitutions and ontology used to generate the model files.

# %% [markdown]
# ## Run installation

# %%
print("Installing the gdown package…")
# !pip install --upgrade --no-cache-dir gdown
print()

# CCP data - constitutions and topics
print("Downloading CCP data…")
# !gdown 'https://drive.google.com/uc?id=1KeKZPjskMyd2hLfA6nfkDkTjIV1kPR31' -O data.zip
print("Unzipping data.zip…")
# !unzip -o 'data.zip'
print("Cleaning up…")
# !rm 'data.zip'
# !rm -rf '__MACOSX'
print()

# CCP model
print("Downloading CCP model…")
# !gdown 'https://drive.google.com/uc?id=1xav5fU9fRZxwTzLOwXMOIay8EPCcOnCV' -O model.zip
print("Unzipping model.zip…")
# !unzip -o 'model.zip'
print("Cleaning up…")
# !rm 'model.zip'
# !rm -rf '__MACOSX'
print()

# USE model
print("Downloading USE model…")
# !gdown 'https://drive.google.com/uc?id=1DgCEP8UMpPfZlZWJpQdm0QKc64p8X_Lz' -O use-4.zip
print("Unzipping use-4.zip…")
# !unzip -o 'use-4zip'
print("Cleaning up…")
# !rm 'use-4.zip'
# !rm -rf '__MACOSX'
print()

print("All downloads complete. You're good to go!")
