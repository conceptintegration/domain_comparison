# %% [markdown]
# # Ontology Corpus Comparison Installer
#
# Install the the following resources:
#
# - Ontologies and constitutions used to generate the model files.
# - Pre-compiled model files (if you don't want to build your own).
# - Universal Sentence Encoder (multilingual version 3) used to encode ontology topics and constitution sections.

# %% [markdown]
# ## Run installation

# %%
print("Installing the gdown package…")
# !pip install --upgrade --no-cache-dir gdown
print()

# Data - ontologies and constitutions
print("Downloading ontologies and constitutions…")
# !gdown 'https://drive.google.com/uc?id=1ETfkbMQl6FBo5aQ2Qkf8XZ2-OR5eU5VF' -O data.zip
print("Unzipping data.zip…")
# !unzip -o 'data.zip'
print("Cleaning up…")
# !rm 'data.zip'
# !rm -rf '__MACOSX'
print()

# Model
print("Downloading model…")
# !gdown 'https://drive.google.com/uc?id=1lhj4lqobCMdhVXkBywL5ywoLFxE3T-03' -O model.zip
print("Unzipping model.zip…")
# !unzip -o 'model.zip'
print("Cleaning up…")
# !rm 'model.zip'
# !rm -rf '__MACOSX'
print()

# USE model
print("Downloading USE model…")
# !gdown 'https://drive.google.com/uc?id=127Bl1wJ22CH9zqix8YcbWlmZZOWSoCzY' -O use_ml_3.zip
print("Unzipping use_ml_3.zip…")
# !unzip -o 'use_ml_3.zip'
print("Cleaning up…")
# !rm 'use_ml_3.zip'
# !rm -rf '__MACOSX'
print()

print("All downloads complete. You're good to go!")
# Out:
# Installing the gdown package…
# ...
#
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1ETfkbMQl6FBo5aQ2Qkf8XZ2-OR5eU5VF
# From (redirected): https://drive.google.com/uc?id=1ETfkbMQl6FBo5aQ2Qkf8XZ2-OR5eU5VF&confirm=t&uuid=59352a81-df7e-4096-9258-74eb939a6eb8
# To: /Users/roygardner/python/cicl/semantic/GitHub/ontology_corpus_comparison/data.zip
# 100%|██████████████████████████████████████| 30.8M/30.8M [00:26<00:00, 1.17MB/s]
# Unzipping data.zip…
# Archive:  data.zip
#    creating: data/
#   inflating: data/.DS_Store
#   inflating: __MACOSX/data/._.DS_Store
#    creating: data/ontologies/
#    creating: data/constitutions/
#    creating: data/ontologies/IDEA-GLO/
#   inflating: data/ontologies/.DS_Store
#   inflating: __MACOSX/data/ontologies/._.DS_Store
#    creating: data/ontologies/NC-DCC/
#    creating: data/ontologies/CCP-FACET/
#   inflating: data/constitutions/.DS_Store
#   inflating: __MACOSX/data/constitutions/._.DS_Store
# ...
